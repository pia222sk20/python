# %%
# 라이브러리 불러오기
import pandas as pd

# Timestamp의 배열 만들기 - 월 간격, 월의 시작일 기준
ts_ms = pd.date_range(start='2024-01-01',    # 날짜 범위의 시작
                   end='2024-12-01',                 # 날짜 범위의 끝
                   periods=100,                # 생성할 Timestamp의 개수
                   freq='MS',                # 시간 간격 (MS: 월의 시작일)
                   tz='Asia/Seoul')          # 시간대(timezone)

print(ts_ms)
# Out:
# DatetimeIndex(['2024-01-01 00:00:00+09:00', '2024-02-01 00:00:00+09:00',
#                '2024-03-01 00:00:00+09:00', '2024-04-01 00:00:00+09:00',
#                '2024-05-01 00:00:00+09:00', '2024-06-01 00:00:00+09:00',
#                '2024-07-01 00:00:00+09:00', '2024-08-01 00:00:00+09:00',
#                '2024-09-01 00:00:00+09:00', '2024-10-01 00:00:00+09:00',
#                '2024-11-01 00:00:00+09:00', '2024-12-01 00:00:00+09:00',
#                '2025-01-01 00:00:00+09:00', '2025-02-01 00:00:00+09:00',
#                '2025-03-01 00:00:00+09:00', '2025-04-01 00:00:00+09:00',
#                '2025-05-01 00:00:00+09:00', '2025-06-01 00:00:00+09:00',
#                '2025-07-01 00:00:00+09:00', '2025-08-01 00:00:00+09:00',
#                '2025-09-01 00:00:00+09:00', '2025-10-01 00:00:00+09:00',
#                '2025-11-01 00:00:00+09:00', '2025-12-01 00:00:00+09:00',
#                '2026-01-01 00:00:00+09:00', '2026-02-01 00:00:00+09:00',
#                '2026-03-01 00:00:00+09:00', '2026-04-01 00:00:00+09:00',
#                '2026-05-01 00:00:00+09:00', '2026-06-01 00:00:00+09:00',
#                '2026-07-01 00:00:00+09:00', '2026-08-01 00:00:00+09:00',
#                '2026-09-01 00:00:00+09:00', '2026-10-01 00:00:00+09:00',
#                '2026-11-01 00:00:00+09:00', '2026-12-01 00:00:00+09:00',
#                '2027-01-01 00:00:00+09:00', '2027-02-01 00:00:00+09:00',
#                '2027-03-01 00:00:00+09:00', '2027-04-01 00:00:00+09:00',
#                '2027-05-01 00:00:00+09:00', '2027-06-01 00:00:00+09:00',
#                '2027-07-01 00:00:00+09:00', '2027-08-01 00:00:00+09:00',
#                '2027-09-01 00:00:00+09:00', '2027-10-01 00:00:00+09:00',
#                '2027-11-01 00:00:00+09:00', '2027-12-01 00:00:00+09:00',
#                '2028-01-01 00:00:00+09:00', '2028-02-01 00:00:00+09:00',
#                '2028-03-01 00:00:00+09:00', '2028-04-01 00:00:00+09:00',
#                '2028-05-01 00:00:00+09:00', '2028-06-01 00:00:00+09:00',
#                '2028-07-01 00:00:00+09:00', '2028-08-01 00:00:00+09:00',
#                '2028-09-01 00:00:00+09:00', '2028-10-01 00:00:00+09:00',
#                '2028-11-01 00:00:00+09:00', '2028-12-01 00:00:00+09:00',
#                '2029-01-01 00:00:00+09:00', '2029-02-01 00:00:00+09:00',
#                '2029-03-01 00:00:00+09:00', '2029-04-01 00:00:00+09:00',
#                '2029-05-01 00:00:00+09:00', '2029-06-01 00:00:00+09:00',
#                '2029-07-01 00:00:00+09:00', '2029-08-01 00:00:00+09:00',
#                '2029-09-01 00:00:00+09:00', '2029-10-01 00:00:00+09:00',
#                '2029-11-01 00:00:00+09:00', '2029-12-01 00:00:00+09:00',
#                '2030-01-01 00:00:00+09:00', '2030-02-01 00:00:00+09:00',
#                '2030-03-01 00:00:00+09:00', '2030-04-01 00:00:00+09:00',
#                '2030-05-01 00:00:00+09:00', '2030-06-01 00:00:00+09:00',
#                '2030-07-01 00:00:00+09:00', '2030-08-01 00:00:00+09:00',
#                '2030-09-01 00:00:00+09:00', '2030-10-01 00:00:00+09:00',
#                '2030-11-01 00:00:00+09:00', '2030-12-01 00:00:00+09:00',
#                '2031-01-01 00:00:00+09:00', '2031-02-01 00:00:00+09:00',
#                '2031-03-01 00:00:00+09:00', '2031-04-01 00:00:00+09:00',
#                '2031-05-01 00:00:00+09:00', '2031-06-01 00:00:00+09:00',
#                '2031-07-01 00:00:00+09:00', '2031-08-01 00:00:00+09:00',
#                '2031-09-01 00:00:00+09:00', '2031-10-01 00:00:00+09:00',
#                '2031-11-01 00:00:00+09:00', '2031-12-01 00:00:00+09:00',
#                '2032-01-01 00:00:00+09:00', '2032-02-01 00:00:00+09:00',
#                '2032-03-01 00:00:00+09:00', '2032-04-01 00:00:00+09:00'],
#               dtype='datetime64[ns, Asia/Seoul]', freq='MS')

# %%
# 월 간격, 월의 마지막 날 기준
ts_me = pd.date_range('2024-01-01', periods=6, 
                       freq='ME',              # 시간 간격 (ME: 월의 마지막 날)
                       tz='Asia/Seoul')        # 시간대(timezone)
print(ts_me)
# Out:
# DatetimeIndex(['2024-01-31 00:00:00+09:00', '2024-02-29 00:00:00+09:00',
#                '2024-03-31 00:00:00+09:00', '2024-04-30 00:00:00+09:00',
#                '2024-05-31 00:00:00+09:00', '2024-06-30 00:00:00+09:00'],
#               dtype='datetime64[ns, Asia/Seoul]', freq='ME')

# %%
# 분기(3개월) 간격, 월의 첫째 날 기준
ts_3m = pd.date_range('2024-01-01', periods=6, 
                       freq='3MS',             # 시간 간격 (3MS: 3개월)
                       tz='Asia/Seoul')        # 시간대(timezone)
print(ts_3m)
# Out:
# DatetimeIndex(['2024-01-01 00:00:00+09:00', '2024-04-01 00:00:00+09:00',
#                '2024-07-01 00:00:00+09:00', '2024-10-01 00:00:00+09:00',
#                '2025-01-01 00:00:00+09:00', '2025-04-01 00:00:00+09:00'],
#               dtype='datetime64[ns, Asia/Seoul]', freq='3MS')
